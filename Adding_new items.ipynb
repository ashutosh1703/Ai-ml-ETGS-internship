# %% [markdown]
# # Record1 and json file

# %%
record1 = {
           '5000-10000':{
                         'samsung':{'model':"A1", 'color':"black", 'specs':6123 ,'units':20 ,'amt':5000},
                         'Oneplus':{'model':"nord", 'color':"blue", 'specs':8256,'units':40 ,'amt':5555},
                         'vivo':{'model': "y1s", 'color':"olive", 'specs':364 ,'units':56 ,'amt':6789},
                         'oppo':{'model':"A33", 'color':"green", 'specs':6128, 'units':76 ,'amt':7865},
                         'realme':{'model':"c11", 'color':"blue", 'specs':464, 'units':35 ,'amt':5890}
                       },
           '10000-20000':{
                          'samsung':{'model':"A2", 'color':"Astroidblack", 'specs':6123 ,'units':40 ,'amt':19867 },
                          'Oneplus':{'model':"nord2", 'color':"pearlblue", 'specs':8256 ,'units':60 ,'amt':17897},
                          'vivo':{'model': "z32s", 'color':"pink", 'specs':364 ,'units':34 ,'amt':18965},
                          'oppo':{'model':"A9", 'color':"olivegreen", 'specs':6128 ,'units': 66 ,'amt':18796},
                          'realme':{'model':"B7", 'color':"darkblue", 'specs':464 ,'units':87 ,'amt':15897}
                       },
           '20000-30000':{
                           'samsung':{'model':"A32", 'color':"White", 'specs':6123 ,'units':65 ,'amt':23456},
                           'Oneplus':{'model':"nord3", 'color':"silver", 'specs':8256 ,'units':86 ,'amt':23587},
                           'vivo':{'model': "y450", 'color':"grey", 'specs':364 ,'units':69 ,'amt':26578},
                           'oppo':{'model':"f30", 'color':"golden", 'specs':6128 ,'units':98 ,'amt':27689},
                           'realme':{'model':"c32", 'color':"silver", 'specs':464 ,'units':92 ,'amt':29999}
                       },
           '30000-40000':{
                         'samsung':{'model':"s20", 'color':"black", 'specs':6123 ,'units':73 ,'amt':31256  },
                         'Oneplus':{'model':"sR", 'color':"blue", 'specs':8256 ,'units':78 ,'amt':36909},
                         'vivo':{'model': "x7", 'color':"yellow", 'specs':364 ,'units':46,'amt':39999},
                         'oppo':{'model':"yt54", 'color':"pink", 'specs':6128 ,'units':57,'amt':38769},
                         'realme':{'model':"c230", 'color':"blue", 'specs':464 ,'units':75,'amt':37658}
                       },
           '40000-50000':{
                         'samsung':{'model':"A50", 'color':"black", 'specs':6123 ,'units':98 ,'amt':43567  },
                         'Oneplus':{'model':"Dt", 'color':"blue", 'specs':8256 ,'units':71,'amt':45556},
                         'vivo':{'model': "y51l", 'color':"purple", 'specs':364 ,'units':43,'amt':49987},
                         'oppo':{'model':"Spro", 'color':"voilet", 'specs':6128 ,'units':69 ,'amt':46798},
                         'realme':{'model':"x7max", 'color':"astroidblack", 'specs':464 ,'units':79 ,'amt':49564}
                       },
           '50000-100000':{
                           'samsung':{'model':"s50", 'color':"black", 'specs':6123 ,'units':78 ,'amt':59989 },
                           'Oneplus':{'model':"N80", 'color':"blue", 'specs':8256 ,'units':99,'amt':78245},
                           'vivo':{'model': "s70", 'color':"olive", 'specs':364 ,'units':53 ,'amt':68990},
                           'oppo':{'model':"A45 plus", 'color':"green", 'specs':6128 , 'units':76 ,'amt':98679},
                           'realme':{'model':"r90", 'color':"blue", 'specs':464 , 'units':99 ,'amt':87908}
                       },
          }

# %%
import json
js = json.dumps(record1)

fd=open("record1.json",'w')
fd.write(js)
fd.close()

# %%
fd = open("record1.json",'r')
r = fd.read()
fd.close()

record1 = json.loads(r)

# %%
record1
# Out:
# {'5000-10000': {'samsung': {'model': 'A1',
#    'color': 'black',
#    'specs': 6123,
#    'units': 20,
#    'amt': 5000},
#   'Oneplus': {'model': 'nord',
#    'color': 'blue',
#    'specs': 8256,
#    'units': 40,
#    'amt': 5555},
#   'vivo': {'model': 'y1s',
#    'color': 'olive',
#    'specs': 364,
#    'units': 56,
#    'amt': 6789},
#   'oppo': {'model': 'A33',
#    'color': 'green',
#    'specs': 6128,
#    'units': 76,
#    'amt': 7865},
#   'realme': {'model': 'c11',
#    'color': 'blue',
#    'specs': 464,
#    'units': 35,
#    'amt': 5890}},
#  '10000-20000': {'samsung': {'model': 'A2',
#    'color': 'Astroidblack',
#    'specs': 6123,
#    'units': 40,
#    'amt': 19867},
#   'Oneplus': {'model': 'nord2',
#    'color': 'pearlblue',
#    'specs': 8256,
#    'units': 60,
#    'amt': 17897},
#   'vivo': {'model': 'z32s',
#    'color': 'pink',
#    'specs': 364,
#    'units': 34,
#    'amt': 18965},
#   'oppo': {'model': 'A9',
#    'color': 'olivegreen',
# ...

# %% [markdown]
# # new item to record1

# %%
amt_range=str(input("enter the range you want to add 1.5000-10000 2.10000-20000 3.20000-30000 4.30000-40000 5.40000-50000 6.50000-100000:"))
cmp=str(input("enter the company: "))
model=str(input("enter model no.: "))
color=str(input("enter color : "))
specs=input("enter processor version: ")
units=input("enter no. of units: ")
amt=input("enter amount: ")

record1[amt_range][cmp] = {'model':model, 'color':color, 'specs':specs ,'units':units ,'amt':amt  }

js = json.dumps(record1)

fd=open("record1.json",'w')
fd.write(js)
fd.close()
# Out:
# enter the range you want to add 1.5000-10000 2.10000-20000 3.20000-30000 4.30000-40000 5.40000-50000 6.50000-100000:10000-20000
# enter the company: apple
# enter model no.: 456
# enter color : green
# enter processor version: m1
# enter no. of units: 90
# enter amount: 19999

# %%
record1
# Out:
# {'5000-10000': {'samsung': {'model': 'A1',
#    'color': 'black',
#    'specs': 6123,
#    'units': 20,
#    'amt': 5000},
#   'Oneplus': {'model': 'nord',
#    'color': 'blue',
#    'specs': 8256,
#    'units': 40,
#    'amt': 5555},
#   'vivo': {'model': 'y1s',
#    'color': 'olive',
#    'specs': 364,
#    'units': 56,
#    'amt': 6789},
#   'oppo': {'model': 'A33',
#    'color': 'green',
#    'specs': 6128,
#    'units': 76,
#    'amt': 7865},
#   'realme': {'model': 'c11',
#    'color': 'blue',
#    'specs': 464,
#    'units': 35,
#    'amt': 5890}},
#  '10000-20000': {'samsung': {'model': 'A2',
#    'color': 'Astroidblack',
#    'specs': 6123,
#    'units': 40,
#    'amt': 19867},
#   'Oneplus': {'model': 'nord2',
#    'color': 'pearlblue',
#    'specs': 8256,
#    'units': 60,
#    'amt': 17897},
#   'vivo': {'model': 'z32s',
#    'color': 'pink',
#    'specs': 364,
#    'units': 34,
#    'amt': 18965},
#   'oppo': {'model': 'A9',
#    'color': 'olivegreen',
# ...
